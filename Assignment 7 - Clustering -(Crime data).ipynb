# %%
import pandas as pd
import numpy as np
df = pd.read_csv("crime_data.csv")
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
df.dtypes
# Out:
# Unnamed: 0     object
# Murder        float64
# Assault         int64
# UrbanPop        int64
# Rape          float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  50 non-null     object
#  1   Murder      50 non-null     float64
#  2   Assault     50 non-null     int64
#  3   UrbanPop    50 non-null     int64
#  4   Rape        50 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.1+ KB

# %%
df.rename(columns={df.columns[0]:"State"}, inplace = True)
df
# Out:
#              State  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %%
df.shape
# Out:
# (50, 5)

# %%
## Hierarchical Clustering

from sklearn.preprocessing import MinMaxScaler

# Normalizing Dataset

scaler = MinMaxScaler()

scaler_df = scaler.fit_transform(df.iloc[:,1:])
print(scaler_df)
# Out:
# [[0.74698795 0.65410959 0.44067797 0.35917313]
#  [0.55421687 0.74657534 0.27118644 0.96124031]
#  [0.43975904 0.85273973 0.81355932 0.6124031 ]
#  [0.48192771 0.49657534 0.30508475 0.31524548]
#  [0.4939759  0.79109589 1.         0.86046512]
#  [0.42771084 0.54452055 0.77966102 0.81136951]
#  [0.15060241 0.22260274 0.76271186 0.09819121]
#  [0.30722892 0.6609589  0.6779661  0.21963824]
#  [0.87951807 0.99315068 0.81355932 0.63565891]
#  [1.         0.56849315 0.47457627 0.47803618]
#  [0.27108434 0.00342466 0.86440678 0.33333333]
#  [0.10843373 0.25684932 0.37288136 0.17829457]
#  [0.57831325 0.69863014 0.86440678 0.43152455]
#  [0.38554217 0.23287671 0.55932203 0.35400517]
#  [0.08433735 0.03767123 0.42372881 0.10335917]
#  [0.31325301 0.23972603 0.57627119 0.27648579]
#  [0.53614458 0.21917808 0.33898305 0.23255814]
#  [0.87951807 0.69863014 0.57627119 0.38501292]
#  [0.07831325 0.13013699 0.3220339  0.0129199 ]
#  [0.63253012 0.87328767 0.59322034 0.52971576]
# ...

# %%
# Create Dendrograms
plt.figure(figsize=(10, 7))  
dendograms=sch.dendrogram(sch.linkage(X,'complete'))

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=4,affinity='euclidean',linkage="ward")
Y=cluster.fit_predict(X)
# Out:
# C:\Users\ABCD\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
Clusters=pd.DataFrame(Y,columns=['Clusters'])
X['h_clusterid'] = cluster.labels_
X
# Out:
#       Murder   Assault  UrbanPop      Rape  h_clusterid
# 0   0.746988  0.654110  0.440678  0.359173            3
# 1   0.554217  0.746575  0.271186  0.961240            2
# 2   0.439759  0.852740  0.813559  0.612403            2
# 3   0.481928  0.496575  0.305085  0.315245            0
# 4   0.493976  0.791096  1.000000  0.860465            2
# 5   0.427711  0.544521  0.779661  0.811370            2
# 6   0.150602  0.222603  0.762712  0.098191            0
# 7   0.307229  0.660959  0.677966  0.219638            0
# 8   0.879518  0.993151  0.813559  0.635659            2
# 9   1.000000  0.568493  0.474576  0.478036            3
# 10  0.271084  0.003425  0.864407  0.333333            0
# 11  0.108434  0.256849  0.372881  0.178295            1
# 12  0.578313  0.698630  0.864407  0.431525            2
# 13  0.385542  0.232877  0.559322  0.354005            0
# 14  0.084337  0.037671  0.423729  0.103359            1
# 15  0.313253  0.239726  0.576271  0.276486            0
# ...

# %%
X["h_clusterid"].value_counts()
# Out:
# h_clusterid
# 0    18
# 2    13
# 1    12
# 3     7
# Name: count, dtype: int64

# %%
# Adding clusters to dataset
df['clustersid_HC']=cluster.labels_
df
# Out:
#              State  Murder  Assault  UrbanPop  Rape  clustersid_HC
# 0          Alabama    13.2      236        58  21.2              3
# 1           Alaska    10.0      263        48  44.5              2
# 2          Arizona     8.1      294        80  31.0              2
# 3         Arkansas     8.8      190        50  19.5              0
# 4       California     9.0      276        91  40.6              2
# 5         Colorado     7.9      204        78  38.7              2
# 6      Connecticut     3.3      110        77  11.1              0
# 7         Delaware     5.9      238        72  15.8              0
# 8          Florida    15.4      335        80  31.9              2
# 9          Georgia    17.4      211        60  25.8              3
# 10          Hawaii     5.3       46        83  20.2              0
# 11           Idaho     2.6      120        54  14.2              1
# 12        Illinois    10.4      249        83  24.0              2
# ...

# %%
# K-Means clustering 
# To check how many clusters are requried

from sklearn.cluster import KMeans
inertia = []
for i in range(1, 11):
    km = KMeans(n_clusters=i,random_state=0)
    km.fit(X)
    inertia.append(km.inertia_)
print(inertia)
# Out:
# C:\Users\ABCD\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\ABCD\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ABCD\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
# Elbow method to see variance in inertia by clusters
plt.plot(range(1, 11), inertia)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('inertia')
plt.show()

# %%
# From the graph we can see that the optimal number of clusters is 4

# %%
# Scree plot
import seaborn as sns
d1 = {"kvalue": range(1, 11),'inertiavalues':inertia}
d2 = pd.DataFrame(d1)
sns.barplot(x='kvalue',y="inertiavalues", data=d2)
# Out:
# <Axes: xlabel='kvalue', ylabel='inertiavalues'>

# %%
# kvalue=clusters
# Here the variance in inertia b/w 4th and 5th cluster is less so we can go with 4 clusters

# %%
KM=KMeans(n_clusters=4,n_init=10,max_iter=300)
Y=KM.fit_predict(X)
# Out:
# C:\Users\ABCD\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
Y=pd.DataFrame(Y)
Y.value_counts()
# Out:
# 2    18
# 3    13
# 0    12
# 1     7
# Name: count, dtype: int64

# %%
df1=pd.concat([X,Y],axis=1)

# %%
#DBScan

# Normalize heterogenous numerical data using standard scalar fit transform to dataset

from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
df_norm=StandardScaler().fit_transform(X)
df_norm
# Out:
# array([[ 1.25517927,  0.79078716, -0.52619514, -0.00345116,  1.69893248],
#        [ 0.51301858,  1.11805959, -1.22406668,  2.50942392,  0.76545309],
#        [ 0.07236067,  1.49381682,  1.00912225,  1.05346626,  0.76545309],
#        [ 0.23470832,  0.23321191, -1.08449238, -0.18679398, -1.10150567],
#        [ 0.28109336,  1.2756352 ,  1.77678094,  2.08881393,  0.76545309],
#        [ 0.02597562,  0.40290872,  0.86954794,  1.88390137,  0.76545309],
#        [-1.04088037, -0.73648418,  0.79976079, -1.09272319, -1.10150567],
#        [-0.43787481,  0.81502956,  0.45082502, -0.58583422, -1.10150567],
#        [ 1.76541475,  1.99078607,  1.00912225,  1.1505301 ,  0.76545309],
#        [ 2.22926518,  0.48775713, -0.38662083,  0.49265293,  1.69893248],
#        [-0.57702994, -1.51224105,  1.21848371, -0.11129987, -1.10150567],
#        [-1.20322802, -0.61527217, -0.80534376, -0.75839217, -0.16802629],
#        [ 0.60578867,  0.94836277,  1.21848371,  0.29852525,  0.76545309],
# ...

# %%
dbscan=DBSCAN(eps=1,min_samples=4)
dbscan.fit(X)
# Out:
# DBSCAN(eps=1, min_samples=4)

# %%
# Noisy samples are given the label -1.
dbscan.labels_
# Out:
# array([0, 1, 1, 2, 1, 1, 2, 2, 1, 0, 2, 3, 1, 2, 3, 2, 2, 0, 3, 1, 2, 1,
#        3, 0, 1, 3, 3, 1, 3, 2, 1, 1, 0, 3, 2, 2, 2, 2, 2, 0, 3, 0, 1, 2,
#        3, 2, 2, 3, 3, 2], dtype=int64)

# %%
# Adding clusters to dataset
df['clustersDB']=dbscan.labels_
df
# Out:
#              State  Murder  Assault  UrbanPop  Rape  clustersid_HC  clustersDB
# 0          Alabama    13.2      236        58  21.2              3           0
# 1           Alaska    10.0      263        48  44.5              2           1
# 2          Arizona     8.1      294        80  31.0              2           1
# 3         Arkansas     8.8      190        50  19.5              0           2
# 4       California     9.0      276        91  40.6              2           1
# 5         Colorado     7.9      204        78  38.7              2           1
# 6      Connecticut     3.3      110        77  11.1              0           2
# 7         Delaware     5.9      238        72  15.8              0           2
# 8          Florida    15.4      335        80  31.9              2           1
# 9          Georgia    17.4      211        60  25.8              3           0
# 10          Hawaii     5.3       46        83  20.2              0           2
# ...

# %%
# Plot Clusters

plt.figure(figsize=(10,7))
plt.scatter(df['clustersDB'],df['Murder'],c=dbscan.labels_) 
plt.title('DBSCAN Clustering plot')
plt.xlabel('Clusters')
plt.ylabel('Murder')
# Out:
# Text(0, 0.5, 'Murder')

# %%
plt.figure(figsize=(10,7))
plt.scatter(df['clustersDB'],df['Assault'],c=dbscan.labels_) 
plt.title('DBSCAN Clustering plot')
plt.xlabel('Clusters')
plt.ylabel('Assault')
# Out:
# Text(0, 0.5, 'Assault')

# %%
plt.figure(figsize=(10,7))  
plt.scatter(df['clustersDB'],df['UrbanPop'],c=dbscan.labels_) 
plt.title('DBSCAN Clustering plot')
plt.xlabel('Clusters')
plt.ylabel('UrbanPop')
# Out:
# Text(0, 0.5, 'UrbanPop')

# %%
plt.figure(figsize=(10,7))
plt.scatter(df['clustersDB'],df['Rape'],c=dbscan.labels_) 
plt.title('DBSCAN Clustering plot')
plt.xlabel('Clusters')
plt.ylabel('Rape')
# Out:
# Text(0, 0.5, 'Rape')
